# %%
print("ufsygdsgd")
# Out:
# ufsygdsgd

# %%
import logging

# %%
logging.basicConfig(filename = "test.log")

# %%
logging.info("this is my info log")
logging.warning("this is my warning log")
logging.error("this is my error log")

# %%
logging.shutdown()

# %%
pwd
# Out:
# 'C:\\Users\\chand'

# %%
DEBUG
INFO
WARNING
ERROR
CRITICAL
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-bb5333ccd896> in <module>
# ----> 1 DEBUG
#       2 INFO
#       3 WARNING
#       4 ERROR
#       5 CRITICAL
#
# NameError: name 'DEBUG' is not defined

# %%
logging.basicConfig(filename = "test.log", level = logging.INFO)

# %%
logging.info("this is my info log")
logging.warning("this is my warning log")
logging.error("this is my error log")

# %%
logging.basicConfig(filename = "test2.log", level = logging.DEBUG, format = '%(asctime)s %(message)s')

# %%
logging.info("this is my info log")
logging.warning("this is my warning log")
logging.debug("this is my debug log")
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character '%' (0x25) at index 11
# Call stack:
#   File "C:\Users\chand\anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\chand\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\chand\anaconda3\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\chand\anaconda3\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\chand\anaconda3\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\chand\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-9-33e62dac4e31>", line 1, in <module>
#     logging.info("this is my info log")
# Message: 'this is my info log'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character '%' (0x25) at index 11
# Call stack:
#   File "C:\Users\chand\anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\chand\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\chand\anaconda3\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\chand\anaconda3\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\chand\anaconda3\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\chand\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-9-33e62dac4e31>", line 2, in <module>
#     logging.warning("this is my warning log")
# Message: 'this is my warning log'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character '%' (0x25) at index 11
# Call stack:
#   File "C:\Users\chand\anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\chand\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\chand\anaconda3\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\chand\anaconda3\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\chand\anaconda3\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\chand\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-9-33e62dac4e31>", line 3, in <module>
#     logging.debug("this is my debug log")
# Message: 'this is my debug log'
# Arguments: ()

# %%
import logging
logging.basicConfig(filename="test3.log", level = logg)

# %%
def divbyzero(a,b):
    logging.info("this is a start of my code and i am try to enter %s and %s ", a,b)
    try:
        div = a/b
        logging.info("executed successfully")
    except Exception as e :
        logging.error("Error has happened")
        logging.exception("Exception occured" +str(e))

# %%
divbyzero(4,5)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character '%' (0x25) at index 11
# Call stack:
#   File "C:\Users\chand\anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\chand\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\chand\anaconda3\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\chand\anaconda3\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\chand\anaconda3\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\chand\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-13-2fd0cd515d95>", line 1, in <module>
#     divbyzero(4,5)
#   File "<ipython-input-12-bd5999fd0fbc>", line 2, in divbyzero
#     logging.info("this is a start of my code and i am try to enter %s and %s ", a,b)
# Message: 'this is a start of my code and i am try to enter %s and %s '
# Arguments: (4, 5)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 1081, in emit
#     msg = self.format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 925, in format
#     return fmt.format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 667, in format
#     s = self.formatMessage(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 636, in formatMessage
#     return self._style.format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 436, in format
#     return self._format(record)
#   File "C:\Users\chand\anaconda3\lib\logging\__init__.py", line 432, in _format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character '%' (0x25) at index 11
# Call stack:
#   File "C:\Users\chand\anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\chand\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\chand\anaconda3\lib\site-packages\traitlets\config\application.py", line 845, in launch_instance
#     app.start()
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\chand\anaconda3\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\chand\anaconda3\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\chand\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "C:\Users\chand\anaconda3\lib\site-packages\tornado\gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\chand\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2894, in run_cell
#     result = self._run_cell(
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3165, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\chand\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-13-2fd0cd515d95>", line 1, in <module>
#     divbyzero(4,5)
#   File "<ipython-input-12-bd5999fd0fbc>", line 5, in divbyzero
#     logging.info("executed successfully")
# Message: 'executed successfully'
# Arguments: ()
